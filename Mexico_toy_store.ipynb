# %%
import pandas as pd

import numpy as np

# %%
description = pd.read_csv(r"D:\My Statistics\Pandas\New folder\Maven Toys Data\data_dictionary.csv")

# %%
stores = pd.read_csv(r"D:\My Statistics\Pandas\New folder\Maven Toys Data\stores.csv")

# %%
sales = pd.read_csv(r"D:\My Statistics\Pandas\New folder\Maven Toys Data\sales.csv")

# %%
products = pd.read_csv(r"D:\My Statistics\Pandas\New folder\Maven Toys Data\products.csv")

# %%
inventory = pd.read_csv(r"D:\My Statistics\Pandas\New folder\Maven Toys Data\inventory.csv")

# %%
date = pd.read_csv(r"D:\My Statistics\Pandas\New folder\Maven Toys Data\calendar.csv")

# %%
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829262 entries, 0 to 829261
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   Sale_ID     829262 non-null  int64
#  1   Date        829262 non-null  object
#  2   Store_ID    829262 non-null  int64
#  3   Product_ID  829262 non-null  int64
#  4   Units       829262 non-null  int64
# dtypes: int64(4), object(1)
# memory usage: 31.6+ MB

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 5 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_ID        35 non-null     int64
#  1   Product_Name      35 non-null     object
#  2   Product_Category  35 non-null     object
#  3   Product_Cost      35 non-null     object
#  4   Product_Price     35 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.5+ KB

# %%
sale_prod = pd.merge(sales , products , on = 'Product_ID')

# %%
sale_prod.head()
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1  2022-01-01        24           4      1  Chutes & Ladders
# 1        2  2022-01-01        28           1      1     Action Figure
# 2        3  2022-01-01         6           8      1     Deck Of Cards
# 3        4  2022-01-01        48           7      1          Dart Gun
# 4        5  2022-01-01        44          18      1       Lego Bricks
#
#     Product_Category Product_Cost Product_Price
# 0              Games       $9.99        $12.99
# 1               Toys       $9.99        $15.99
# 2              Games       $3.99         $6.99
# 3  Sports & Outdoors      $11.99        $15.99
# 4               Toys      $34.99        $39.99

# %%
stores.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Store_ID         50 non-null     int64
#  1   Store_Name       50 non-null     object
#  2   Store_City       50 non-null     object
#  3   Store_Location   50 non-null     object
#  4   Store_Open_Date  50 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 2.1+ KB

# %%
toy_sales = pd.merge(sale_prod, stores , on = 'Store_ID')

# %%
inventory.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1593 entries, 0 to 1592
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Store_ID       1593 non-null   int64
#  1   Product_ID     1593 non-null   int64
#  2   Stock_On_Hand  1593 non-null   int64
# dtypes: int64(3)
# memory usage: 37.5 KB

# %%
toy_sales.head()
# Out:
#    Sale_ID        Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1  2022-01-01        24           4      1  Chutes & Ladders
# 1        2  2022-01-01        28           1      1     Action Figure
# 2        3  2022-01-01         6           8      1     Deck Of Cards
# 3        4  2022-01-01        48           7      1          Dart Gun
# 4        5  2022-01-01        44          18      1       Lego Bricks
#
#     Product_Category Product_Cost Product_Price                   Store_Name  \
# 0              Games       $9.99        $12.99   Maven Toys Aguascalientes 1
# 1               Toys       $9.99        $15.99           Maven Toys Puebla 2
# 2              Games       $3.99         $6.99         Maven Toys Mexicali 1
# 3  Sports & Outdoors      $11.99        $15.99         Maven Toys Saltillo 2
# 4               Toys      $34.99        $39.99           Maven Toys Puebla 3
#
#        Store_City Store_Location Store_Open_Date
# ...

# %%
toy_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829262 entries, 0 to 829261
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Sale_ID           829262 non-null  int64
#  1   Date              829262 non-null  object
#  2   Store_ID          829262 non-null  int64
#  3   Product_ID        829262 non-null  int64
#  4   Units             829262 non-null  int64
#  5   Product_Name      829262 non-null  object
#  6   Product_Category  829262 non-null  object
#  7   Product_Cost      829262 non-null  object
#  8   Product_Price     829262 non-null  object
#  9   Store_Name        829262 non-null  object
#  10  Store_City        829262 non-null  object
#  11  Store_Location    829262 non-null  object
#  12  Store_Open_Date   829262 non-null  object
# dtypes: int64(4), object(9)
# memory usage: 82.2+ MB

# %%
toy_sales['Date'] = pd.to_datetime(toy_sales['Date'])

# %%
toy_sales['Date'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 829262 entries, 0 to 829261
# Series name: Date
# Non-Null Count   Dtype
# --------------   -----
# 829262 non-null  datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 6.3 MB

# %%
toy_sales.head()
# Out:
#    Sale_ID       Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1 2022-01-01        24           4      1  Chutes & Ladders
# 1        2 2022-01-01        28           1      1     Action Figure
# 2        3 2022-01-01         6           8      1     Deck Of Cards
# 3        4 2022-01-01        48           7      1          Dart Gun
# 4        5 2022-01-01        44          18      1       Lego Bricks
#
#     Product_Category Product_Cost Product_Price                   Store_Name  \
# 0              Games       $9.99        $12.99   Maven Toys Aguascalientes 1
# 1               Toys       $9.99        $15.99           Maven Toys Puebla 2
# 2              Games       $3.99         $6.99         Maven Toys Mexicali 1
# 3  Sports & Outdoors      $11.99        $15.99         Maven Toys Saltillo 2
# 4               Toys      $34.99        $39.99           Maven Toys Puebla 3
#
#        Store_City Store_Location Store_Open_Date
# ...

# %%
toy_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829262 entries, 0 to 829261
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Sale_ID           829262 non-null  int64
#  1   Date              829262 non-null  datetime64[ns]
#  2   Store_ID          829262 non-null  int64
#  3   Product_ID        829262 non-null  int64
#  4   Units             829262 non-null  int64
#  5   Product_Name      829262 non-null  object
#  6   Product_Category  829262 non-null  object
#  7   Product_Cost      829262 non-null  object
#  8   Product_Price     829262 non-null  object
#  9   Store_Name        829262 non-null  object
#  10  Store_City        829262 non-null  object
#  11  Store_Location    829262 non-null  object
#  12  Store_Open_Date   829262 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(8)
# memory usage: 82.2+ MB

# %%
toy_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829262 entries, 0 to 829261
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Sale_ID           829262 non-null  int64
#  1   Date              829262 non-null  datetime64[ns]
#  2   Store_ID          829262 non-null  int64
#  3   Product_ID        829262 non-null  int64
#  4   Units             829262 non-null  int64
#  5   Product_Name      829262 non-null  object
#  6   Product_Category  829262 non-null  object
#  7   Product_Cost      829262 non-null  object
#  8   Product_Price     829262 non-null  object
#  9   Store_Name        829262 non-null  object
#  10  Store_City        829262 non-null  object
#  11  Store_Location    829262 non-null  object
#  12  Store_Open_Date   829262 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(8)
# memory usage: 82.2+ MB

# %%
toy_sales['Product_Price'] = toy_sales['Product_Price'].replace('[\$,]', '', regex=True).astype(float)

# %%
toy_sales['Product_Cost'] = toy_sales['Product_Cost'].replace('[\$,]' , '' , regex = True).astype(float)

# %%
toy_sales.head()
# Out:
#    Sale_ID       Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1 2022-01-01        24           4      1  Chutes & Ladders
# 1        2 2022-01-01        28           1      1     Action Figure
# 2        3 2022-01-01         6           8      1     Deck Of Cards
# 3        4 2022-01-01        48           7      1          Dart Gun
# 4        5 2022-01-01        44          18      1       Lego Bricks
#
#     Product_Category  Product_Cost  Product_Price  \
# 0              Games          9.99          12.99
# 1               Toys          9.99          15.99
# 2              Games          3.99           6.99
# 3  Sports & Outdoors         11.99          15.99
# 4               Toys         34.99          39.99
#
#                     Store_Name      Store_City Store_Location Store_Open_Date
# 0  Maven Toys Aguascalientes 1  Aguascalientes       Downtown      2010-07-31
# 1          Maven Toys Puebla 2          Puebla       Downtown      2011-04-01
# ...

# %% [markdown]
# ### Finding revenue

# %%
toy_sales['Revenue'] = toy_sales['Units'] * toy_sales['Product_Price']

# %%
# Total revenue of all product

# %%
total_revenue = round(toy_sales['Revenue'].sum() , 3)

print(f'${total_revenue}')
# Out:
# $14444572.35

# %%
### creating profit column

# %%
toy_sales['Profit'] = toy_sales['Revenue'] - toy_sales['Product_Cost']

# %%
net_profit = toy_sales['Profit'].sum()


print(net_profit)
# Out:
# 6171472.97

# %% [markdown]
# ### Finding Revenue by each product category

# %%
revenue_product_cat = toy_sales.groupby('Product_Category')['Revenue'].sum().sort_values(ascending = False)

print(revenue_product_cat)
# Out:
# Product_Category
# Toys                 5093241.00
# Art & Crafts         2705364.26
# Electronics          2246771.25
# Games                2226836.27
# Sports & Outdoors    2172359.57
# Name: Revenue, dtype: float64

# %% [markdown]
# The best selling products are toys for this store.
#
# The revenue from Toys is about $ 5093241.
#
# This amount is the highest revenue for this store.

# %%
profit_product_cat = toy_sales.groupby('Product_Category')['Profit'].sum().sort_values(ascending = False)


profit_product_cat
# Out:
# Product_Category
# Toys                 1821172.27
# Electronics          1283326.50
# Art & Crafts         1271718.99
# Games                 952373.33
# Sports & Outdoors     842881.88
# Name: Profit, dtype: float64

# %%
product_categor_stats = toy_sales.groupby('Product_Category').agg(Revenue =('Revenue' , 'sum') , 
                                                                  Profit = ('Profit' , 'sum'),
                                                                 Unit_Sold = ('Units' , 'sum')).sort_values('Profit' , ascending = False)

# %%
product_categor_stats
# Out:
#                       Revenue      Profit  Unit_Sold
# Product_Category
# Toys               5093241.00  1821172.27     267200
# Electronics        2246771.25  1283326.50     134075
# Art & Crafts       2705364.26  1271718.99     325574
# Games              2226836.27   952373.33     194673
# Sports & Outdoors  2172359.57   842881.88     169043

# %%
product_categor_stats['Profit_Percent'] = (product_categor_stats['Profit']/product_categor_stats['Profit'].sum()) * 100

# %%
product_categor_stats
# Out:
#                       Revenue      Profit  Unit_Sold  Profit_Percent
# Product_Category
# Toys               5093241.00  1821172.27     267200       29.509524
# Electronics        2246771.25  1283326.50     134075       20.794493
# Art & Crafts       2705364.26  1271718.99     325574       20.606409
# Games              2226836.27   952373.33     194673       15.431864
# Sports & Outdoors  2172359.57   842881.88     169043       13.657710

# %%
product_categor_stats['Profit_Margin'] = product_categor_stats['Profit'] / product_categor_stats['Revenue']

product_categor_stats
# Out:
#                       Revenue      Profit  Unit_Sold  Profit_Percent  \
# Product_Category
# Toys               5093241.00  1821172.27     267200       29.509524
# Electronics        2246771.25  1283326.50     134075       20.794493
# Art & Crafts       2705364.26  1271718.99     325574       20.606409
# Games              2226836.27   952373.33     194673       15.431864
# Sports & Outdoors  2172359.57   842881.88     169043       13.657710
#
#                    Profit_Margin
# Product_Category
# Toys                    0.357566
# Electronics             0.571187
# Art & Crafts            0.470073
# Games                   0.427680
# Sports & Outdoors       0.388003

# %% [markdown]
# ### Analyse on Profit

# %% [markdown]
# We got 29 % of profit from selling Toys.
#
# The profit gaining from Electronics and Art&Crafts are not quite different.
#
# The profit from selling video games is 15%.
#
# However, Electronics make 57% of profit from it's revenue.
# This is the higest profit margin. We should make more promotion on Eelectionics.

# %%
product_categor_stats.to_csv(r"D:\My Statistics\Pandas\My reults and Analyst\product_categor_stats.csv")
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 product_categor_stats.to_csv(r"D:\My Statistics\Pandas\My reults and Analyst\product_categor_stats.csv")
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ### Analyze on each product

# %%
product_summary = toy_sales.groupby(['Product_Category' , 'Product_Name']).agg(Revenue = ('Revenue' , 'sum') , 
                                                        Profit = ('Profit' , 'sum') , 
                                                        Quantity_sold = ('Units' , 'sum'))

# %%
product_summary.sort_values(['Product_Category' , 'Profit'] , ascending = False)
# Out:
#                                             Revenue      Profit  Quantity_sold
# Product_Category  Product_Name
# Toys              Lego Bricks            2388882.63   708312.93          59737
#                   Action Figure           926748.42   442263.39          57958
#                   Animal Figures          507766.11   185588.61          39089
#                   Dinosaur Figures        434889.88   167711.99          29012
#                   Dino Egg                420213.64   138685.45          38236
#                   Plush Pony              109705.12    61806.40           5488
#                   Hot Wheels 5-Pack       135727.41    52831.17          22659
#                   Mr. Potatohead           85963.95    46942.15           8605
#                   Teddy Bear               83343.84    17030.18           6416
# Sports & Outdoors Splash Balls            541629.52   209573.11          60248
# ...

# %% [markdown]
# ### finding top selling product

# %%
product_summary = toy_sales.groupby('Product_Name').agg(Unit_Sold = ('Units' , 'sum') , 
                                                        Revenue = ('Revenue' , 'sum') ,
                                                        Profit = ('Profit' , 'sum')).sort_values(['Unit_Sold','Profit'] , ascending = False)

# %%
product_summary['Profit_Margin'] = product_summary['Profit'] / product_summary['Revenue']

product_summary['Profit_Percent'] = (product_summary['Profit'] / product_summary['Profit'].sum()) * 100

# %%
product_summary.to_csv(r'D:\My Statistics\Pandas\Mexico toy sales result\product_summary.csv')

# %% [markdown]
# Colorbuds is best selling product.
#
# We could sold 104368 Units. This show that Colorbuds is the most popular product among our customers.
#
# We should stock them to avoid shortage.
#
# It is also the highest profit margin. If we sell 1 unit of Colorbuds, we get 67 net profit.
#
# We obtain 17% of profit from selling Colorbuds.This percent is the highest profit share.

# %%
product_summary.sort_values('Profit' , ascending = False)
# Out:
#                        Unit_Sold     Revenue      Profit  Profit_Margin  \
# Product_Name
# Colorbuds                 104368  1564476.32  1054290.20       0.673893
# Lego Bricks                59737  2388882.63   708312.93       0.296504
# Action Figure              57958   926748.42   442263.39       0.477221
# Magic Sand                 60598   968962.02   419252.95       0.432683
# Deck Of Cards              84034   587397.66   315746.49       0.537534
# Glass Marbles              37518   412322.82   265525.89       0.643976
# Barrel O' Slime            91663   365735.37   258120.15       0.705757
# Rubik's Cube               45672   912983.28   216716.31       0.237372
# Splash Balls               60248   541629.52   209573.11       0.386931
# Dart Gun                   31588   505092.12   190918.15       0.377987
# Animal Figures             39089   507766.11   185588.61       0.365500
# Kids Makeup Kit            24433   488415.67   185560.15       0.379923
# ...

# %%
top_four_market_share = product_summary['Profit_Percent'].loc['Colorbuds':'Magic Sand'].sum()

print(top_four_market_share)
# Out:
# 36.08122178974723

# %% [markdown]
# Top 4 Best Profit Produts are
#
# Colorbuds
#
# Lego Bricks
#
# Action Figures
#
# Magic Sand
#
# Their profit share is about 37%. This amount is too much for four products.
#
# So, we shold keep this product selling and promotion.

# %%
product_summary
# Out:
#                        Unit_Sold     Revenue      Profit  Profit_Margin  \
# Product_Name
# Colorbuds                 104368  1564476.32  1054290.20       0.673893
# PlayDoh Can               103128   308352.72   179333.06       0.581584
# Barrel O' Slime            91663   365735.37   258120.15       0.705757
# Deck Of Cards              84034   587397.66   315746.49       0.537534
# Magic Sand                 60598   968962.02   419252.95       0.432683
# Splash Balls               60248   541629.52   209573.11       0.386931
# Lego Bricks                59737  2388882.63   708312.93       0.296504
# Action Figure              57958   926748.42   442263.39       0.477221
# Rubik's Cube               45672   912983.28   216716.31       0.237372
# Animal Figures             39089   507766.11   185588.61       0.365500
# Dino Egg                   38236   420213.64   138685.45       0.330036
# Glass Marbles              37518   412322.82   265525.89       0.643976
# ...

# %%
low_sale_qty = product_summary['Unit_Sold'].quantile(0.25)

# %%
product_price = toy_sales[['Product_Name' ,'Product_Price']].drop_duplicates()

# %%
product_price
# Out:
#                  Product_Name  Product_Price
# 0            Chutes & Ladders          12.99
# 1               Action Figure          15.99
# 2               Deck Of Cards           6.99
# 3                    Dart Gun          15.99
# 4                 Lego Bricks          39.99
# 5                Splash Balls           8.99
# 7              Animal Figures          12.99
# 8          Mini Ping Pong Set           9.99
# 13                   Dino Egg          10.99
# 15                   Nerf Gun          19.99
# 21            PlayDoh Toolkit           4.99
# 24       Mini Basketball Hoop          24.99
# 27              Uno Card Game           7.99
# 34                  Toy Robot          25.99
# 39                  Colorbuds          14.99
# 40              Glass Marbles          10.99
# 42           Classic Dominoes           9.99
# 49               Rubik's Cube          19.99
# 66                 Teddy Bear          12.99
# 93                   Monopoly          19.99
# ...

# %%
product_summary = pd.merge(product_summary , product_price , on = 'Product_Name')

# %%
product_summary
# Out:
#              Product_Name  Unit_Sold     Revenue      Profit  Profit_Margin  \
# 0               Colorbuds     104368  1564476.32  1054290.20       0.673893
# 1             PlayDoh Can     103128   308352.72   179333.06       0.581584
# 2         Barrel O' Slime      91663   365735.37   258120.15       0.705757
# 3           Deck Of Cards      84034   587397.66   315746.49       0.537534
# 4              Magic Sand      60598   968962.02   419252.95       0.432683
# 5            Splash Balls      60248   541629.52   209573.11       0.386931
# 6             Lego Bricks      59737  2388882.63   708312.93       0.296504
# 7           Action Figure      57958   926748.42   442263.39       0.477221
# 8            Rubik's Cube      45672   912983.28   216716.31       0.237372
# 9          Animal Figures      39089   507766.11   185588.61       0.365500
# 10               Dino Egg      38236   420213.64   138685.45       0.330036
# ...

# %%
high_price = product_summary['Product_Price'].quantile(0.75)

print(high_price)
# Out:
# 19.99

# %%
product_summary.sort_values(['Unit_Sold' , 'Product_Price'] , ascending = [True , False])
# Out:
#              Product_Name  Unit_Sold     Revenue      Profit  Profit_Margin  \
# 34   Mini Basketball Hoop       2647    66148.53    42936.35       0.649090
# 33          Uno Card Game       2710    21652.90    11282.89       0.521080
# 32               Monopoly       3385    67666.15    25668.17       0.379335
# 31       Chutes & Ladders       3829    49738.71    12775.71       0.256856
# 30               Playfoam       4158    45696.42    34476.54       0.754469
# 29       Classic Dominoes       4471    44665.29    10555.98       0.236335
# 28             Plush Pony       5488   109705.12    61806.40       0.563387
# 27        PlayDoh Playset       6298   157387.02    30040.69       0.190871
# 26             Teddy Bear       6416    83343.84    17030.18       0.204336
# 25  Supersoaker Water Gun       6793   101827.07    28831.95       0.283146
# 24     Foam Disk Launcher       7620    91363.80    30123.92       0.329714
# ...

# %%
low_sale_high_price = product_summary[(product_summary['Unit_Sold'] <= low_sale_qty) & (product_summary['Product_Price'] >= high_price)]

# %%
low_sale_high_price
# Out:
#             Product_Name  Unit_Sold    Revenue    Profit  Profit_Margin  \
# 27       PlayDoh Playset       6298  157387.02  30040.69       0.190871
# 28            Plush Pony       5488  109705.12  61806.40       0.563387
# 32              Monopoly       3385   67666.15  25668.17       0.379335
# 34  Mini Basketball Hoop       2647   66148.53  42936.35       0.649090
#
#     Profit_Percent  Product_Price
# 27        0.486767          24.99
# 28        1.001485          19.99
# 32        0.415916          19.99
# 34        0.695723          24.99

# %% [markdown]
# PlayDoh Playset is the worst. Its profit margin is about 19 %.
#
# Mini Basketball Hoop is lowest sale amount but its profit margin is the highest amont these products.
#
# We should take some action to get better sales.

# %%
toy_sales.head()
# Out:
#    Sale_ID       Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1 2022-01-01        24           4      1  Chutes & Ladders
# 1        2 2022-01-01        28           1      1     Action Figure
# 2        3 2022-01-01         6           8      1     Deck Of Cards
# 3        4 2022-01-01        48           7      1          Dart Gun
# 4        5 2022-01-01        44          18      1       Lego Bricks
#
#     Product_Category  Product_Cost  Product_Price  \
# 0              Games          9.99          12.99
# 1               Toys          9.99          15.99
# 2              Games          3.99           6.99
# 3  Sports & Outdoors         11.99          15.99
# 4               Toys         34.99          39.99
#
#                     Store_Name      Store_City Store_Location Store_Open_Date  \
# 0  Maven Toys Aguascalientes 1  Aguascalientes       Downtown      2010-07-31
# 1          Maven Toys Puebla 2          Puebla       Downtown      2011-04-01
# ...

# %% [markdown]
# ### Creating Pivot Table

# %%
store_category = pd.pivot_table(toy_sales , index = 'Store_Name' , columns = 'Product_Category' ,values = 'Revenue', aggfunc = 'sum')

# %%
store_category['Total_Revenue'] = store_category.sum(axis = 1)

# %%
toy_sales['Store_Name'].nunique()
# Out:
# 50

# %%
store_category.sort_values('Total_Revenue' , ascending = False)
# Out:
# Product_Category               Art & Crafts  Electronics      Games  \
# Store_Name
# Maven Toys Ciudad de Mexico 2      90076.29    112851.72  103915.27
# Maven Toys Guadalajara 3           81488.50     80031.12   67524.62
# Maven Toys Ciudad de Mexico 1      77326.87     42529.64   72040.97
# Maven Toys Toluca 1               108295.02     31583.30   52794.89
# Maven Toys Monterrey 2             64691.13     67519.80   61643.28
# Maven Toys Guadalajara 4           41273.42     77909.04   43952.90
# Maven Toys Hermosillo 3            69883.14     84740.47   49067.08
# Maven Toys Xalapa 2                82595.12     46296.85   45230.89
# Maven Toys Ciudad de Mexico 3      67190.32     30499.87   47150.87
# Maven Toys Saltillo 1              50556.55     61207.74   55236.93
# Maven Toys Monterrey 4             63496.25     38184.54   23966.00
# Maven Toys Ciudad de Mexico 4      47368.45     61600.42   44924.62
# Maven Toys Hermosillo 2            67676.83     48694.14   43893.92
# ...

# %%
low_revenue_sale= store_category['Total_Revenue'].quantile(0.25)


print(low_sale_store)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 4
#       1 low_revenue_sale= store_category['Total_Revenue'].quantile(0.25)
# ----> 4 print(low_sale_store)
#
# NameError: name 'low_sale_store' is not defined

# %%
low_sale_stores = store_category[store_category['Total_Revenue'] <= low_revenue_sale].sort_values('Total_Revenue' , ascending = False)

# %%
len(low_sale_stores)
# Out:
# 13

# %%
low_sale_stores
# Out:
# Product_Category               Art & Crafts  Electronics     Games  \
# Store_Name
# Maven Toys Chilpancingo 1          42729.77     42525.42  32224.10
# Maven Toys Oaxaca 1                52574.74     24710.67  36408.09
# Maven Toys Aguascalientes 1        32623.95     43525.87  44464.80
# Maven Toys Pachuca 1               60647.79     24851.90  39257.10
# Maven Toys Hermosillo 1            39595.74     59007.64  37842.84
# Maven Toys Merida 1                50810.72     36882.51  41706.60
# Maven Toys Zacatecas 1             59771.06     22380.88  29087.49
# Maven Toys Tuxtla Gutierrez 1      46897.88     30791.92  37370.12
# Maven Toys Toluca 2                51278.54     23614.56  30733.25
# Maven Toys Durango 1               44596.75     42766.66  31707.49
# Maven Toys Cuernavaca 1            47858.66     18016.30  28032.43
# Maven Toys La Paz 1                41824.70     26575.65  34230.14
# Maven Toys Campeche 2              45118.79     32399.40  34844.09
#
# ...

# %% [markdown]
# Maven Toys Campeche 2 is the lowest sale revenue.
#
# We need to think about somethings such as store situations , employee services , store manager , population from Campeche.
#
# The average salary of people around Campeche 2 store.

# %%
Higher_sale_amount = store_category['Total_Revenue'].quantile(0.75)

print(Higher_sale_amount)
# Out:
# 321049.41500000004

# %%
Mid_sale_amount = store_category['Total_Revenue'].quantile(0.5)

print(Mid_sale_amount)
# Out:
# 270882.395

# %%
low_sale_amount = store_category['Total_Revenue'].quantile(0.25)

print(low_sale_amount)
# Out:
# 243906.8725

# %%
Higher_sales_stores = store_category[store_category['Total_Revenue'] > Higher_sale_amount].sort_values('Total_Revenue' , ascending = False)   # greater than 75% quantile

# %%
Mid_sales_stores = store_category[(store_category['Total_Revenue'] > Mid_sale_amount) & 
    (store_category['Total_Revenue'] <= Higher_sale_amount)].sort_values('Total_Revenue' , ascending = False) # between 50 and 75

# %%
low_sales_stores =store_category[(store_category['Total_Revenue'] > low_sale_amount) & 
    (store_category['Total_Revenue'] <= Mid_sale_amount)].sort_values('Total_Revenue' , ascending = False) # between 25 and 50

# %%
lowes_sales_stores = store_category[store_category['Total_Revenue'] <= low_sale_amount].sort_values('Total_Revenue' , ascending = False) # less and equal 25%

# %%
print('The number of High Sales Stores')
len(Higher_sales_stores)
# Out:
# The number of High Sales Stores
# 13

# %%
print('The numwer of Mid Sales Stores')
len(Mid_sales_stores)
# Out:
# The numwer of Mid Sales Stores
# 12

# %%
print('The number of Lowest Sales Stores')
len(lowes_sales_stores)
# Out:
# The number of Lowest Sales Stores
# 13

# %%
print('The number of Low Sales Stores')
len(low_sales_stores)
# Out:
# The number of Low Sales Stores
# 12

# %%
Higher_sales_stores
# Out:
# Product_Category               Art & Crafts  Electronics      Games  \
# Store_Name
# Maven Toys Ciudad de Mexico 2      90076.29    112851.72  103915.27
# Maven Toys Guadalajara 3           81488.50     80031.12   67524.62
# Maven Toys Ciudad de Mexico 1      77326.87     42529.64   72040.97
# Maven Toys Toluca 1               108295.02     31583.30   52794.89
# Maven Toys Monterrey 2             64691.13     67519.80   61643.28
# Maven Toys Guadalajara 4           41273.42     77909.04   43952.90
# Maven Toys Hermosillo 3            69883.14     84740.47   49067.08
# Maven Toys Xalapa 2                82595.12     46296.85   45230.89
# Maven Toys Ciudad de Mexico 3      67190.32     30499.87   47150.87
# Maven Toys Saltillo 1              50556.55     61207.74   55236.93
# Maven Toys Monterrey 4             63496.25     38184.54   23966.00
# Maven Toys Ciudad de Mexico 4      47368.45     61600.42   44924.62
# Maven Toys Hermosillo 2            67676.83     48694.14   43893.92
#
# ...

# %%
Mid_sales_stores
# Out:
# Product_Category              Art & Crafts  Electronics     Games  \
# Store_Name
# Maven Toys Guanajuato 1           41975.12     47477.23  49190.55
# Maven Toys Campeche 1             52691.79     26754.51  62632.04
# Maven Toys Ciudad Victoria 1      55622.93     65608.32  36589.87
# Maven Toys Mexicali 1             48109.67    104047.75  45010.63
# Maven Toys Mexicali 2             41508.07     42860.73  41833.46
# Maven Toys Monterrey 3            37798.88     43613.69  68564.21
# Maven Toys Puebla 2               66113.24     29422.49  33115.94
# Maven Toys Guanajuato 2           46138.23     51110.15  41579.81
# Maven Toys Monterrey 1            52697.81     43667.83  32749.08
# Maven Toys Santiago 1             67925.79     37017.03  38674.52
# Maven Toys Guanajuato 3           46075.99     22678.87  32049.24
# Maven Toys Morelia 1              26646.27     51667.74  90167.66
#
# Product_Category              Sports & Outdoors       Toys  Total_Revenue
# Store_Name
# ...

# %%
low_sales_stores
# Out:
# Product_Category              Art & Crafts  Electronics     Games  \
# Store_Name
# Maven Toys Chihuahua 2            53671.16     23108.50  47366.73
# Maven Toys Puebla 3               34425.84     46807.09  35632.66
# Maven Toys Xalapa 1               37788.82     45681.51  37350.55
# Maven Toys San Luis Potosi 1      60622.70     38681.27  34279.65
# Maven Toys Guadalajara 2          52375.39     49580.35  40552.35
# Maven Toys Guadalajara 1          60242.69     22958.99  47414.16
# Maven Toys Chetumal 1             41758.12     36392.38  36827.68
# Maven Toys Puebla 1               48596.97     54277.30  47864.80
# Maven Toys Villahermosa 1         55024.69     39722.27  40246.14
# Maven Toys Culiacan 1             67762.83     22288.25  35621.87
# Maven Toys Saltillo 2             43446.42     44840.33  44507.79
# Maven Toys Chihuahua 1            38097.86     44808.64  37764.10
#
# Product_Category              Sports & Outdoors       Toys  Total_Revenue
# Store_Name
# ...

# %%
lowest_sales_stores
# Out:
# Product_Category               Art & Crafts  Electronics     Games  \
# Store_Name
# Maven Toys Chilpancingo 1          42729.77     42525.42  32224.10
# Maven Toys Oaxaca 1                52574.74     24710.67  36408.09
# Maven Toys Aguascalientes 1        32623.95     43525.87  44464.80
# Maven Toys Pachuca 1               60647.79     24851.90  39257.10
# Maven Toys Hermosillo 1            39595.74     59007.64  37842.84
# Maven Toys Merida 1                50810.72     36882.51  41706.60
# Maven Toys Zacatecas 1             59771.06     22380.88  29087.49
# Maven Toys Tuxtla Gutierrez 1      46897.88     30791.92  37370.12
# Maven Toys Toluca 2                51278.54     23614.56  30733.25
# Maven Toys Durango 1               44596.75     42766.66  31707.49
# Maven Toys Cuernavaca 1            47858.66     18016.30  28032.43
# Maven Toys La Paz 1                41824.70     26575.65  34230.14
# Maven Toys Campeche 2              45118.79     32399.40  34844.09
#
# ...

# %% [markdown]
# ### The Final Analysis on Stores and Actions To Take

# %% [markdown]
# We have 13 High Sales Stores , 12 Mid Sales Stores , 12 Low Sales Stores and 12 Lowest Sales Stores.
#
# We must congraculation to our High Sales Stores and Mid Sales Stores as their sales revenue.
#
# We need to take some actions to our Low and Lowest Sales Stores.
#
# We need to think and take some actions to our lowest Sales Stores quickly.
#
# We should check the situation of Maven Toys Campeche 2. We need to talk the manager and employees of Maven Toys Campeche 2.

# %%
toy_sales.head()
# Out:
#    Sale_ID       Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1 2022-01-01        24           4      1  Chutes & Ladders
# 1        2 2022-01-01        28           1      1     Action Figure
# 2        3 2022-01-01         6           8      1     Deck Of Cards
# 3        4 2022-01-01        48           7      1          Dart Gun
# 4        5 2022-01-01        44          18      1       Lego Bricks
#
#     Product_Category  Product_Cost  Product_Price  \
# 0              Games          9.99          12.99
# 1               Toys          9.99          15.99
# 2              Games          3.99           6.99
# 3  Sports & Outdoors         11.99          15.99
# 4               Toys         34.99          39.99
#
#                     Store_Name      Store_City Store_Location Store_Open_Date  \
# 0  Maven Toys Aguascalientes 1  Aguascalientes       Downtown      2010-07-31
# 1          Maven Toys Puebla 2          Puebla       Downtown      2011-04-01
# ...

# %% [markdown]
# ### Profit By location

# %%
profit_city = toy_sales.groupby(['Store_City','Store_Name'])['Profit'].sum().sort_index()

# %%
profit_city
# Out:
# Store_City        Store_Name
# Aguascalientes    Maven Toys Aguascalientes 1       96268.23
# Campeche          Maven Toys Campeche 1            146063.39
#                   Maven Toys Campeche 2             83053.28
# Chetumal          Maven Toys Chetumal 1            109427.79
# Chihuahua         Maven Toys Chihuahua 1           102120.28
#                   Maven Toys Chihuahua 2           118152.54
# Chilpancingo      Maven Toys Chilpancingo 1         98469.65
# Ciudad Victoria   Maven Toys Ciudad Victoria 1     124510.33
# Cuernavaca        Maven Toys Cuernavaca 1           88167.69
# Cuidad de Mexico  Maven Toys Ciudad de Mexico 1    183155.03
#                   Maven Toys Ciudad de Mexico 2    277790.67
#                   Maven Toys Ciudad de Mexico 3    145785.17
#                   Maven Toys Ciudad de Mexico 4    138892.39
# Culiacan          Maven Toys Culiacan 1            108762.85
# Durango           Maven Toys Durango 1              87250.88
# ...

# %%
summary_city = toy_sales.groupby(['Store_City' , 'Store_Name']).agg(Profit = ('Profit' , 'sum'),
                                                                    Quantity = ('Units' , 'sum'),
                                                                    Revenue = ('Revenue' , 'sum'))

# %%
summary_city['Cumulative_Profit'] = summary_city['Profit'].cumsum()

# %%
summary_city
# Out:
#                                                    Profit  Quantity  \
# Store_City       Store_Name
# Aguascalientes   Maven Toys Aguascalientes 1     96268.23     17865
# Campeche         Maven Toys Campeche 1          146063.39     24556
#                  Maven Toys Campeche 2           83053.28     16277
# Chetumal         Maven Toys Chetumal 1          109427.79     18965
# Chihuahua        Maven Toys Chihuahua 1         102120.28     18070
#                  Maven Toys Chihuahua 2         118152.54     22326
# Chilpancingo     Maven Toys Chilpancingo 1       98469.65     18327
# Ciudad Victoria  Maven Toys Ciudad Victoria 1   124510.33     20501
# Cuernavaca       Maven Toys Cuernavaca 1         88167.69     17074
# Cuidad de Mexico Maven Toys Ciudad de Mexico 1  183155.03     33479
#                  Maven Toys Ciudad de Mexico 2  277790.67     42757
#                  Maven Toys Ciudad de Mexico 3  145785.17     26634
# ...

# %%
summary_city = summary_city.drop('Cumulative_Profit' , axis = 1)

# %%
summary_city
# Out:
#                                                    Profit  Quantity    Revenue
# Store_City       Store_Name
# Aguascalientes   Maven Toys Aguascalientes 1     96268.23     17865  239997.35
# Campeche         Maven Toys Campeche 1          146063.39     24556  311786.44
#                  Maven Toys Campeche 2           83053.28     16277  206055.23
# Chetumal         Maven Toys Chetumal 1          109427.79     18965  258919.35
# Chihuahua        Maven Toys Chihuahua 1         102120.28     18070  248008.30
#                  Maven Toys Chihuahua 2         118152.54     22326  268704.74
# Chilpancingo     Maven Toys Chilpancingo 1       98469.65     18327  242539.73
# Ciudad Victoria  Maven Toys Ciudad Victoria 1   124510.33     20501  294803.99
# Cuernavaca       Maven Toys Cuernavaca 1         88167.69     17074  221587.26
# Cuidad de Mexico Maven Toys Ciudad de Mexico 1  183155.03     33479  433556.21
# ...

# %%
summary_city['Cumulative_Profit'] = summary_city.groupby('Store_City')['Profit'].cumsum()

# %%
summary_city
# Out:
#                                                    Profit  Quantity  \
# Store_City       Store_Name
# Aguascalientes   Maven Toys Aguascalientes 1     96268.23     17865
# Campeche         Maven Toys Campeche 1          146063.39     24556
#                  Maven Toys Campeche 2           83053.28     16277
# Chetumal         Maven Toys Chetumal 1          109427.79     18965
# Chihuahua        Maven Toys Chihuahua 1         102120.28     18070
#                  Maven Toys Chihuahua 2         118152.54     22326
# Chilpancingo     Maven Toys Chilpancingo 1       98469.65     18327
# Ciudad Victoria  Maven Toys Ciudad Victoria 1   124510.33     20501
# Cuernavaca       Maven Toys Cuernavaca 1         88167.69     17074
# Cuidad de Mexico Maven Toys Ciudad de Mexico 1  183155.03     33479
#                  Maven Toys Ciudad de Mexico 2  277790.67     42757
#                  Maven Toys Ciudad de Mexico 3  145785.17     26634
# ...

# %% [markdown]
# ### City Analysis

# %%
profit_city = toy_sales.groupby('Store_City').agg(Sold_Units = ('Units' ,'sum') , 
                                                  Total_Revenue = ('Revenue' , 'sum'),
                                                  Total_Profit = ('Profit' , 'sum')).sort_values('Total_Profit' , ascending = False)

# %%
profit_city['Profit_Margin'] = profit_city['Total_Profit']/ profit_city['Total_Revenue']

# %%
profit_city
# Out:
#                   Sold_Units  Total_Revenue  Total_Profit  Profit_Margin
# Store_City
# Cuidad de Mexico      125599     1649492.01     745623.26       0.452032
# Monterrey              93730     1261845.70     565291.93       0.447988
# Guadalajara            96454     1322099.46     560945.26       0.424284
# Hermosillo             66816      903388.84     410831.19       0.454767
# Guanajuato             64317      869055.83     365918.03       0.421052
# Puebla                 61171      808710.29     338703.37       0.418819
# Toluca                 48632      633521.68     262902.77       0.414986
# Mexicali               44415      586175.85     256928.40       0.438313
# Xalapa                 44223      610119.77     256016.84       0.419617
# Saltillo               42903      579514.97     244912.87       0.422617
# Campeche               40833      517841.67     229116.67       0.442445
# Chihuahua              40396      516713.04     220272.82       0.426296
# ...

# %% [markdown]
# Cuidad de Mexico is the highest sales city and the highest profit city for our store.
#
# We should analze the population and average income of people in each city.
#
# we must take decison based on upon results.
#
# The lowest sales city , La Paz should be promoted the name of our stores to be more popular in that city.

# %% [markdown]
# ### Time Series Analysis
#
# Sales over month

# %%
toy_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 829262 entries, 0 to 829261
# Data columns (total 15 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Sale_ID           829262 non-null  int64
#  1   Date              829262 non-null  datetime64[ns]
#  2   Store_ID          829262 non-null  int64
#  3   Product_ID        829262 non-null  int64
#  4   Units             829262 non-null  int64
#  5   Product_Name      829262 non-null  object
#  6   Product_Category  829262 non-null  object
#  7   Product_Cost      829262 non-null  float64
#  8   Product_Price     829262 non-null  float64
#  9   Store_Name        829262 non-null  object
#  10  Store_City        829262 non-null  object
#  11  Store_Location    829262 non-null  object
#  12  Store_Open_Date   829262 non-null  object
#  13  Revenue           829262 non-null  float64
#  14  Profit            829262 non-null  float64
# ...

# %%
toy_sales.head()
# Out:
#    Sale_ID       Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1 2022-01-01        24           4      1  Chutes & Ladders
# 1        2 2022-01-01        28           1      1     Action Figure
# 2        3 2022-01-01         6           8      1     Deck Of Cards
# 3        4 2022-01-01        48           7      1          Dart Gun
# 4        5 2022-01-01        44          18      1       Lego Bricks
#
#     Product_Category  Product_Cost  Product_Price  \
# 0              Games          9.99          12.99
# 1               Toys          9.99          15.99
# 2              Games          3.99           6.99
# 3  Sports & Outdoors         11.99          15.99
# 4               Toys         34.99          39.99
#
#                     Store_Name      Store_City Store_Location Store_Open_Date  \
# 0  Maven Toys Aguascalientes 1  Aguascalientes       Downtown      2010-07-31
# 1          Maven Toys Puebla 2          Puebla       Downtown      2011-04-01
# ...

# %%
toy_sales['Month'] = toy_sales['Date'].dt.to_period('M')

# %%
toy_sales['Year'] = toy_sales['Date'].dt.to_period('Y')

# %%
toy_sales.head()
# Out:
#    Sale_ID       Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1 2022-01-01        24           4      1  Chutes & Ladders
# 1        2 2022-01-01        28           1      1     Action Figure
# 2        3 2022-01-01         6           8      1     Deck Of Cards
# 3        4 2022-01-01        48           7      1          Dart Gun
# 4        5 2022-01-01        44          18      1       Lego Bricks
#
#     Product_Category  Product_Cost  Product_Price  \
# 0              Games          9.99          12.99
# 1               Toys          9.99          15.99
# 2              Games          3.99           6.99
# 3  Sports & Outdoors         11.99          15.99
# 4               Toys         34.99          39.99
#
#                     Store_Name      Store_City Store_Location Store_Open_Date  \
# 0  Maven Toys Aguascalientes 1  Aguascalientes       Downtown      2010-07-31
# 1          Maven Toys Puebla 2          Puebla       Downtown      2011-04-01
# ...

# %%
toy_sales['Month'].unique()
# Out:
# <PeriodArray>
# ['2022-01', '2022-02', '2022-03', '2022-04', '2022-05', '2022-06', '2022-07',
#  '2022-08', '2022-09', '2022-10', '2022-11', '2022-12', '2023-01', '2023-02',
#  '2023-03', '2023-04', '2023-05', '2023-06', '2023-07', '2023-08', '2023-09']
# Length: 21, dtype: period[M]

# %%
monthly_sales = toy_sales.groupby('Month').agg(Sold_Units = ('Units' , 'sum') , 
                                               Revenue = ('Revenue' , 'sum') , 
                                               Profit = ('Profit' ,'sum')).sort_values(['Month' , 'Profit']  ,ascending =[True , False])

# %%
monthly_sales['Year'] = monthly_sales.index.year

# %%
monthly_sales.columns
# Out:
# Index(['Sold_Units', 'Revenue', 'Profit', 'Year'], dtype='object')

# %%
monthly_sales.index
# Out:
# PeriodIndex(['2022-01', '2022-02', '2022-03', '2022-04', '2022-05', '2022-06',
#              '2022-07', '2022-08', '2022-09', '2022-10', '2022-11', '2022-12',
#              '2023-01', '2023-02', '2023-03', '2023-04', '2023-05', '2023-06',
#              '2023-07', '2023-08', '2023-09'],
#             dtype='period[M]', name='Month')

# %%
monthly_sales = monthly_sales.sort_values(['Year' , 'Profit'] , ascending = (True , False))

monthly_sales
# Out:
#          Sold_Units    Revenue     Profit  Year
# Month
# 2022-12       66031  877203.69  384954.49  2022
# 2022-04       47102  681072.98  310169.14  2022
# 2022-06       47178  661980.22  301485.37  2022
# 2022-05       46910  672369.90  286248.54  2022
# 2022-11       51185  661304.15  275914.74  2022
# 2022-10       47861  623874.39  264391.90  2022
# 2022-07       46177  556034.23  258554.38  2022
# 2022-03       39981  589485.19  257778.95  2022
# 2022-01       38009  542554.91  241801.38  2022
# 2022-02       36935  541351.65  239775.16  2022
# 2022-09       42196  585844.04  238024.71  2022
# 2022-08       39927  489422.73  217855.77  2022
# 2023-03       69336  883515.64  388075.82  2023
# 2023-04       65593  827691.07  358337.75  2023
# 2023-05       63851  825319.49  340568.91  2023
# 2023-07       63614  828348.86  339950.94  2023
# 2023-06       64275  808299.25  327193.46  2023
# 2023-01       56478  747196.22  316703.40  2023
# ...

# %% [markdown]
# In 2022, December is the most highest sale month and March is the most highest sale in 2023.
#
# Those two highest values are close less different.
#
# Every year , August is the lowest sales month and April is the second highest sales.

# %%
monthly_sales.to_csv(r'D:\My Statistics\Pandas\My reults and Analyst\monthly_sales.csv')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 monthly_sales.to_csv(r'D:\My Statistics\Pandas\My reults and Analyst\monthly_sales.csv')
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# ### Weekly Analysis

# %%
toy_sales['Week'] = toy_sales['Date'].dt.to_period('W')

# %%
toy_sales['Date'].dt.('D')
# Out:
#   Cell In[110], line 1
#     toy_sales['Date'].dt.('D')
#                          ^
# SyntaxError: invalid syntax

# %%
toy_sales['Week'] = toy_sales['Date'].dt.isocalendar().week

# %%
toy_sales['Day'] = toy_sales['Date'].dt.weekday

# %%
toy_sales['Day_Name'] = toy_sales['Date'].dt.day_name()

# %%
toy_sales.head()
# Out:
#    Sale_ID       Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1 2022-01-01        24           4      1  Chutes & Ladders
# 1        2 2022-01-01        28           1      1     Action Figure
# 2        3 2022-01-01         6           8      1     Deck Of Cards
# 3        4 2022-01-01        48           7      1          Dart Gun
# 4        5 2022-01-01        44          18      1       Lego Bricks
#
#     Product_Category  Product_Cost  Product_Price  \
# 0              Games          9.99          12.99
# 1               Toys          9.99          15.99
# 2              Games          3.99           6.99
# 3  Sports & Outdoors         11.99          15.99
# 4               Toys         34.99          39.99
#
#                     Store_Name      Store_City Store_Location Store_Open_Date  \
# 0  Maven Toys Aguascalientes 1  Aguascalientes       Downtown      2010-07-31
# 1          Maven Toys Puebla 2          Puebla       Downtown      2011-04-01
# ...

# %%
weekly_trend = toy_sales.groupby(['Week' ,'Day_Name']).agg(Revenue = ('Revenue' ,'sum') ,
                                                           Profit = ('Profit' , 'sum') , 
                                                           Unit_Solds = ('Units' , 'sum')).sort_values(['Week' , 'Profit'] , ascending = (True, False))

# %%
weekly_trend
# Out:
#                  Revenue    Profit  Unit_Solds
# Week Day_Name
# 1    Friday     72196.33  30764.42        4767
#      Thursday   57655.63  27647.13        3937
#      Saturday   50131.21  21208.68        3979
#      Wednesday  38822.34  16304.54        2766
#      Tuesday    34352.02  15214.77        2498
# ...                  ...       ...         ...
# 52   Friday     30857.12  13556.55        2288
#      Thursday   28013.86  11600.10        2114
#      Tuesday    20781.01  10229.66        1599
#      Monday     21157.40   8888.92        1660
#      Wednesday  19095.35   8200.10        1465
#
# [364 rows x 3 columns]

# %%
toy_sales['Year_Week'] = toy_sales['Date'].dt.strftime('%G-W%V')

# %%
toy_sales.head()
# Out:
#    Sale_ID       Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1 2022-01-01        24           4      1  Chutes & Ladders
# 1        2 2022-01-01        28           1      1     Action Figure
# 2        3 2022-01-01         6           8      1     Deck Of Cards
# 3        4 2022-01-01        48           7      1          Dart Gun
# 4        5 2022-01-01        44          18      1       Lego Bricks
#
#     Product_Category  Product_Cost  Product_Price  \
# 0              Games          9.99          12.99
# 1               Toys          9.99          15.99
# 2              Games          3.99           6.99
# 3  Sports & Outdoors         11.99          15.99
# 4               Toys         34.99          39.99
#
#                     Store_Name  ... Store_Location Store_Open_Date Revenue  \
# 0  Maven Toys Aguascalientes 1  ...       Downtown      2010-07-31   12.99
# 1          Maven Toys Puebla 2  ...       Downtown      2011-04-01   15.99
# ...

# %%
weekly_trend = toy_sales.groupby(['Year_Week' ,'Year',  'Day_Name'])[['Revenue' , 'Profit']].sum()

# %%
idx = weekly_trend.groupby('Year_Week')['Profit'].idxmax()

# %%
best_day = weekly_trend.loc[idx]

# %%
best_days_sort = best_day.sort_values(['Year' , 'Profit'] , ascending = (True , False))

# %%
best_days_sort.to_csv(r"D:\My Statistics\Pandas\Mexico toy sales result\best_days.csv")

# %%
best_days_sort
# Out:
#                           Revenue    Profit
# Year_Week Year Day_Name
# 2022-W51  2022 Saturday  50900.14  24800.64
# 2022-W17  2022 Saturday  47547.93  22316.56
# 2022-W24  2022 Saturday  38576.92  20902.54
# 2022-W37  2022 Friday    41578.46  18587.86
# 2022-W10  2022 Saturday  37479.05  17323.70
# ...                           ...       ...
# 2023-W33  2023 Saturday  29331.75  12567.43
# 2023-W36  2023 Friday    32290.09  12314.81
# 2023-W38  2023 Friday    30007.98  11954.28
# 2023-W31  2023 Monday    27930.07  11328.73
# 2023-W32  2023 Friday    29705.85  10898.68
#
# [92 rows x 2 columns]

# %%
toy_sales.head()
# Out:
#    Sale_ID       Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1 2022-01-01        24           4      1  Chutes & Ladders
# 1        2 2022-01-01        28           1      1     Action Figure
# 2        3 2022-01-01         6           8      1     Deck Of Cards
# 3        4 2022-01-01        48           7      1          Dart Gun
# 4        5 2022-01-01        44          18      1       Lego Bricks
#
#     Product_Category  Product_Cost  Product_Price  \
# 0              Games          9.99          12.99
# 1               Toys          9.99          15.99
# 2              Games          3.99           6.99
# 3  Sports & Outdoors         11.99          15.99
# 4               Toys         34.99          39.99
#
#                     Store_Name  ... Store_Location Store_Open_Date Revenue  \
# 0  Maven Toys Aguascalientes 1  ...       Downtown      2010-07-31   12.99
# 1          Maven Toys Puebla 2  ...       Downtown      2011-04-01   15.99
# ...

# %%
store_revenue = pd.pivot_table(toy_sales , index = 'Store_Name' , columns = 'Product_Category' ,values = 'Revenue' , aggfunc = 'sum')

# %%
store_revenue['Total_Revenue'] = store_revenue.sum(axis = 1)

# %%
store_revenue.sort_values('Total_Revenue' , ascending = False)
# Out:
# Product_Category               Art & Crafts  Electronics      Games  \
# Store_Name
# Maven Toys Ciudad de Mexico 2      90076.29    112851.72  103915.27
# Maven Toys Guadalajara 3           81488.50     80031.12   67524.62
# Maven Toys Ciudad de Mexico 1      77326.87     42529.64   72040.97
# Maven Toys Toluca 1               108295.02     31583.30   52794.89
# Maven Toys Monterrey 2             64691.13     67519.80   61643.28
# Maven Toys Guadalajara 4           41273.42     77909.04   43952.90
# Maven Toys Hermosillo 3            69883.14     84740.47   49067.08
# Maven Toys Xalapa 2                82595.12     46296.85   45230.89
# Maven Toys Ciudad de Mexico 3      67190.32     30499.87   47150.87
# Maven Toys Saltillo 1              50556.55     61207.74   55236.93
# Maven Toys Monterrey 4             63496.25     38184.54   23966.00
# Maven Toys Ciudad de Mexico 4      47368.45     61600.42   44924.62
# Maven Toys Hermosillo 2            67676.83     48694.14   43893.92
# ...

# %%
store_revenue.to_csv(r'D:\My Statistics\Pandas\Mexico toy sales result\store_revenue_pd_cat.csv')

# %%
product_analysis = pd.pivot_table(toy_sales , index = 'Month' , columns = 'Product_Name' , values = 'Revenue' , aggfunc = 'sum')

# %%
product_analysis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# PeriodIndex: 21 entries, 2022-01 to 2023-09
# Freq: M
# Data columns (total 35 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Action Figure          21 non-null     float64
#  1   Animal Figures         21 non-null     float64
#  2   Barrel O' Slime        17 non-null     float64
#  3   Chutes & Ladders       21 non-null     float64
#  4   Classic Dominoes       21 non-null     float64
#  5   Colorbuds              21 non-null     float64
#  6   Dart Gun               21 non-null     float64
#  7   Deck Of Cards          21 non-null     float64
#  8   Dino Egg               18 non-null     float64
#  9   Dinosaur Figures       21 non-null     float64
#  10  Etch A Sketch          11 non-null     float64
#  11  Foam Disk Launcher     7 non-null      float64
#  12  Gamer Headphones       15 non-null     float64
#  13  Glass Marbles          21 non-null     float64
# ...

# %%
toy_sales.head()
# Out:
#    Sale_ID       Date  Store_ID  Product_ID  Units      Product_Name  \
# 0        1 2022-01-01        24           4      1  Chutes & Ladders
# 1        2 2022-01-01        28           1      1     Action Figure
# 2        3 2022-01-01         6           8      1     Deck Of Cards
# 3        4 2022-01-01        48           7      1          Dart Gun
# 4        5 2022-01-01        44          18      1       Lego Bricks
#
#     Product_Category  Product_Cost  Product_Price  \
# 0              Games          9.99          12.99
# 1               Toys          9.99          15.99
# 2              Games          3.99           6.99
# 3  Sports & Outdoors         11.99          15.99
# 4               Toys         34.99          39.99
#
#                     Store_Name  ... Store_Location Store_Open_Date Revenue  \
# 0  Maven Toys Aguascalientes 1  ...       Downtown      2010-07-31   12.99
# 1          Maven Toys Puebla 2  ...       Downtown      2011-04-01   15.99
# ...

# %%
### Store vs MOnth

# %%
store_revenue_by_each_moth = pd.pivot_table(toy_sales , index = 'Store_Name' , columns = 'Month' , values = 'Revenue' , aggfunc = 'sum')

# %%
month_over_change = toy_sales.groupby('Month')['Revenue'].sum().pct_change()*100

# %%
month_over_change
# Out:
# Month
# 2022-01          NaN
# 2022-02    -0.221777
# 2022-03     8.891363
# 2022-04    15.536911
# 2022-05    -1.277848
# 2022-06    -1.545233
# 2022-07   -16.004404
# 2022-08   -11.979748
# 2022-09    19.701028
# 2022-10     6.491549
# 2022-11     5.999567
# 2022-12    32.647540
# 2023-01   -14.820671
# 2023-02    -3.287494
# 2023-03    22.263532
# 2023-04    -6.318459
# 2023-05    -0.286530
# 2023-06    -2.062261
# 2023-07     2.480469
# 2023-08   -20.217543
# 2023-09    -0.405914
# Freq: M, Name: Revenue, dtype: float64

# %%
toy_sales.to_csv(r'D:\My Statistics\Pandas\Mexico toy sales result\toy_sales.csv')
